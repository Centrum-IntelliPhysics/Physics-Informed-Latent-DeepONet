# %%
import nbformat
import pandas as pd
import numpy as np
from matplotlib import rc
import matplotlib.pyplot as plt
import numpy as np

from misc_postprocessing import *

# rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
# rc('text', usetex=True)

# %%
# List of 'neval' values
neval_t_list = [8, 16, 32, 64, 128, 256, 512, 1024]
neval_x = 8
neval_values = [(i, neval_x) for i in neval_t_list]
latent_dim = 9

# %%
# Initialize an empty list to store the results
runtime_per_iter_data = []

# Loop over each 'neval_t' and 'neval_x' value
for neval_t, neval_x in neval_values:
    # Paths for all notebooks, moving one folder backward
    a_PI_Vanilla_NO_Forward_AD_einsum_path = f'../results/ForwardAD_neval_x_constant/a_PI-Vanilla-NO_Forward_AD-einsum/output_neval_t={neval_t}_neval_x={neval_x}.ipynb'
    b_PI_Latent_NO_with_PCA_Forward_AD_einsum_path = f'../results/ForwardAD_neval_x_constant/b_PI-Latent-NO_with-PCA_Forward_AD-einsum/output_neval_t={neval_t}_neval_x={neval_x}_latent_dim={latent_dim}.ipynb'

    # Extract runtime and memory for all notebooks
    a_PI_Vanilla_NO_Forward_AD_einsum_runtime, a_PI_Vanilla_NO_Forward_AD_einsum_memory = extract_runtime_and_memory_from_notebook(a_PI_Vanilla_NO_Forward_AD_einsum_path)
    b_PI_Latent_NO_with_PCA_Forward_AD_einsum_runtime, b_PI_Latent_NO_with_PCA_Forward_AD_einsum_memory = extract_runtime_and_memory_from_notebook(b_PI_Latent_NO_with_PCA_Forward_AD_einsum_path)

    # Append the results to the list, with ReverseAD-tiling first, then ForwardAD-einsum
    runtime_per_iter_data.append({
        'neval_t': neval_t,
        'neval_x': neval_x,
        'PI-Vanilla-NO (ForwardAD-einsum) Runtime (sec/iter)': a_PI_Vanilla_NO_Forward_AD_einsum_runtime,
        'PI-Vanilla-NO (ForwardAD-einsum) Memory (MB)': a_PI_Vanilla_NO_Forward_AD_einsum_memory,
        'PI-Latent-NO (with-PCA) (ForwardAD-einsum) Runtime (sec/iter)': b_PI_Latent_NO_with_PCA_Forward_AD_einsum_runtime,
        'PI-Latent-NO (with-PCA) (ForwardAD-einsum) Memory (MB)': b_PI_Latent_NO_with_PCA_Forward_AD_einsum_memory
    })

# Store the runtime and memory data in a DataFrame
df = pd.DataFrame(runtime_per_iter_data)

# Set the index name
df.index.name = 'Evaluation'

# Display the DataFrame
df.style.set_table_styles([dict(selector="th", props=[('max-width', '100px')])])

# Display the DataFrame
df
# Out:
#             neval_t  neval_x  \
# Evaluation
# 0                 8        8
# 1                16        8
# 2                32        8
# 3                64        8
# 4               128        8
# 5               256        8
# 6               512        8
# 7              1024        8
#
#             PI-Vanilla-NO (ForwardAD-einsum) Runtime (sec/iter)  \
# Evaluation
# 0                                                     0.02613
# 1                                                     0.02680
# 2                                                     0.02769
# 3                                                     0.02728
# 4                                                     0.02842
# 5                                                     0.03014
# 6                                                     0.03426
# 7                                                     0.03951
#
#             PI-Vanilla-NO (ForwardAD-einsum) Memory (MB)  \
# Evaluation
# 0                                                 1567.0
# 1                                                 1569.0
# 2                                                 1573.0
# 3                                                 1579.0
# 4                                                 1595.0
# 5                                                 1625.0
# 6                                                 1707.0
# 7                                                 1811.0
#
#             PI-Latent-NO (with-PCA) (ForwardAD-einsum) Runtime (sec/iter)  \
# Evaluation
# 0                                                     0.04153
# 1                                                     0.04077
# 2                                                     0.04048
# 3                                                     0.04062
# 4                                                     0.04141
# 5                                                     0.04341
# 6                                                     0.04827
# 7                                                     0.05839
#
#             PI-Latent-NO (with-PCA) (ForwardAD-einsum) Memory (MB)
# Evaluation
# 0                                                      1793.0
# 1                                                      1803.0
# 2                                                      1819.0
# 3                                                      1839.0
# 4                                                      1899.0
# 5                                                      2059.0
# 6                                                      2393.0
# 7                                                      2859.0

# %%
display(df)

### RUNTIME (sec/iter)

# Plotting the four runtime columns
plt.figure(figsize=(10, 6))

plt.plot(df['neval_t'], df['PI-Vanilla-NO (ForwardAD-einsum) Runtime (sec/iter)'], label='PI-Vanilla-NO', 
         marker='o', linestyle='-', color='blue')
plt.plot(df['neval_t'], df['PI-Latent-NO (with-PCA) (ForwardAD-einsum) Runtime (sec/iter)'], label=f'PI-Latent-NO (with-PCA, latent-dim ={latent_dim})', 
         marker='o', linestyle='-', color='red')

# Setting plot details
plt.xscale('log')  # Logarithmic scale for x-axis
# plt.yscale('log') # Logarithmic scale for y-axis
plt.xlabel('Discretization along t-axis ($neval_t$)') 
plt.ylabel('Runtime (sec/iter)')
plt.xticks(df['neval_t'], [f'{int(n)}' for n in df['neval_t']])  # Custom x-axis labels with superscript
plt.legend(loc='best')
plt.grid(True)
plt.title(f'ForwardAD-einsum, $neval_x={neval_x}$')
plt.show()


### Memory (MB)

# Plotting the four runtime columns
plt.figure(figsize=(10, 6))

plt.plot(df['neval_t'], df['PI-Vanilla-NO (ForwardAD-einsum) Memory (MB)'], label='PI-Vanilla-NO', 
         marker='o', linestyle='-', color='blue')
plt.plot(df['neval_t'], df['PI-Latent-NO (with-PCA) (ForwardAD-einsum) Memory (MB)'], label=f'PI-Latent-NO (with-PCA, latent-dim = {latent_dim})', 
         marker='o', linestyle='-', color='red')

# Setting plot details
plt.xscale('log')  # Logarithmic scale for x-axis
# plt.yscale('log') # Logarithmic scale for y-axis
plt.xlabel('Discretization along t-axis ($neval_t$)') 
plt.ylabel('Memory (MB)')
plt.xticks(df['neval_t'], [f'{int(n)}' for n in df['neval_t']])  # Custom x-axis labels with superscript
plt.legend(loc='best')
plt.grid(True)
plt.title(f'ForwardAD-einsum, $neval_x={neval_x}$')
plt.show()
# Out:
#             neval_t  neval_x  \
# Evaluation
# 0                 8        8
# 1                16        8
# 2                32        8
# 3                64        8
# 4               128        8
# 5               256        8
# 6               512        8
# 7              1024        8
#
#             PI-Vanilla-NO (ForwardAD-einsum) Runtime (sec/iter)  \
# Evaluation
# 0                                                     0.02613
# 1                                                     0.02680
# 2                                                     0.02769
# 3                                                     0.02728
# 4                                                     0.02842
# 5                                                     0.03014
# 6                                                     0.03426
# 7                                                     0.03951
#
#             PI-Vanilla-NO (ForwardAD-einsum) Memory (MB)  \
# Evaluation
# 0                                                 1567.0
# 1                                                 1569.0
# 2                                                 1573.0
# 3                                                 1579.0
# 4                                                 1595.0
# 5                                                 1625.0
# 6                                                 1707.0
# 7                                                 1811.0
#
#             PI-Latent-NO (with-PCA) (ForwardAD-einsum) Runtime (sec/iter)  \
# Evaluation
# 0                                                     0.04153
# 1                                                     0.04077
# 2                                                     0.04048
# 3                                                     0.04062
# 4                                                     0.04141
# 5                                                     0.04341
# 6                                                     0.04827
# 7                                                     0.05839
#
#             PI-Latent-NO (with-PCA) (ForwardAD-einsum) Memory (MB)
# Evaluation
# 0                                                      1793.0
# 1                                                      1803.0
# 2                                                      1819.0
# 3                                                      1839.0
# 4                                                      1899.0
# 5                                                      2059.0
# 6                                                      2393.0
# 7                                                      2859.0
